# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('/content/insurance2.csv')

# %%
data.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges  insuranceclaim
# 0   19    0  27.900         0       1       3  16884.92400               1
# 1   18    1  33.770         1       0       2   1725.55230               1
# 2   28    1  33.000         3       0       2   4449.46200               0
# 3   33    1  22.705         0       0       1  21984.47061               0
# 4   32    1  28.880         0       0       1   3866.85520               1

# %%
x=data[['age','sex','bmi','children','smoker','region','charges']]
y=data['insuranceclaim']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
logmodel=LogisticRegression()

# %%
logmodel.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=logmodel.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
cm=confusion_matrix(y_test,y_pred)
ac=accuracy_score(y_test,y_pred)

# %%
print(cm)
# Out:
# [[ 77  44]
#  [ 22 125]]

# %%
print(ac)
# Out:
# 0.753731343283582

# %%
new_data={'age':25,'sex':1,'bmi':28.5,'children':0,'smoker':1,'region':3,'charges':100}

# %%
index=[1]
my_data=pd.DataFrame(new_data,index)

# %%
print(my_data)
# Out:
#    age  sex   bmi  children  smoker  region  charges
# 1   25    1  28.5         0       1       3      100

# %%
y_pred=logmodel.predict(my_data)

# %%
print(y_pred)
# Out:
# [1]

# %% [markdown]
# USING KNN ALGORITHM

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_classifier=KNeighborsClassifier(n_neighbors=7)

# %%
knn_classifier.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
k_pred=knn_classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
cm=confusion_matrix(y_test,k_pred)
ac=accuracy_score(y_test,k_pred)

# %%
print(cm)
# Out:
# [[ 55  66]
#  [ 26 121]]

# %%
print(ac)
# Out:
# 0.6567164179104478

# %% [markdown]
# USING DECISION TREE ALGORITHM

# %%
from sklearn.tree import DecisionTreeClassifier
tree_classify=DecisionTreeClassifier()

# %%
tree_classify.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
d_pred=tree_classify.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
cm=confusion_matrix(y_test,d_pred)
ac=accuracy_score(y_test,d_pred)

# %%
print(cm)
# Out:
# [[120   1]
#  [  3 144]]

# %%
print(ac)
# Out:
# 0.9850746268656716

# %% [markdown]
# USING RANDOM FOREST ALGORITHM

# %%
from sklearn.ensemble import RandomForestClassifier
forest=RandomForestClassifier()

# %%
forest.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
f_pred=forest.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
cm=confusion_matrix(y_test,f_pred)
ac=accuracy_score(y_test,f_pred)

# %%
print(cm)
# Out:
# [[115   6]
#  [  9 138]]

# %%
print(ac)
# Out:
# 0.9440298507462687
